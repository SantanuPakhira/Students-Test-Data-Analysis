# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#data delimitation
data = pd.read_csv('C:\\Users\\personal\\Desktop\\student-mat.csv')

# %%
#print headers
data.head()
# Out:
#   school;sex;age;address;famsize;Pstatus;Medu;Fedu;Mjob;Fjob;reason;guardian;traveltime;studytime;failures;schoolsup;famsup;paid;activities;nursery;higher;internet;romantic;famrel;freetime;goout;Dalc;Walc;health;absences;G1;G2;G3
# 0  GP;"F";18;"U";"GT3";"A";4;4;"at_home";"teacher...
# 1  GP;"F";17;"U";"GT3";"T";1;1;"at_home";"other";...
# 2  GP;"F";15;"U";"LE3";"T";1;1;"at_home";"other";...
# 3  GP;"F";15;"U";"GT3";"T";4;2;"health";"services...
# 4  GP;"F";16;"U";"GT3";"T";3;3;"other";"other";"h...

# %% [markdown]
# Data Delimitation is required

# %%
#not req #print column headers
list(data)
# Out:
# ['school;sex;age;address;famsize;Pstatus;Medu;Fedu;Mjob;Fjob;reason;guardian;traveltime;studytime;failures;schoolsup;famsup;paid;activities;nursery;higher;internet;romantic;famrel;freetime;goout;Dalc;Walc;health;absences;G1;G2;G3']

# %%
#data delimitation
data = pd.read_csv('C:\\Users\\personal\\Desktop\\student-mat.csv',delimiter=";")

# %%
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# Here we found that the dataset has 33 features with 395 observations

# %%
#print information about data frame
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
# school        395 non-null object
# sex           395 non-null object
# age           395 non-null int64
# address       395 non-null object
# famsize       395 non-null object
# Pstatus       395 non-null object
# Medu          395 non-null int64
# Fedu          395 non-null int64
# Mjob          395 non-null object
# Fjob          395 non-null object
# reason        395 non-null object
# guardian      395 non-null object
# traveltime    395 non-null int64
# studytime     395 non-null int64
# failures      395 non-null int64
# schoolsup     395 non-null object
# famsup        395 non-null object
# paid          395 non-null object
# activities    395 non-null object
# nursery       395 non-null object
# higher        395 non-null object
# internet      395 non-null object
# romantic      395 non-null object
# famrel        395 non-null int64
# ...

# %%
#data characterstics
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
import matplotlib.pyplot as plt
sns.pairplot(data, kind="scatter")
plot.show()

# %%
#not req#print the whole file
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %%
#not req#data sort with one header
data.sort_values(by='school', ascending=True).head()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 238     GP   F   17       R     GT3       T     2     1  at_home  services
# 237     GP   F   16       U     GT3       T     2     1    other     other
# 236     GP   M   17       U     LE3       T     2     2    other     other
# 235     GP   M   16       U     GT3       T     3     2  at_home     other
#
#     ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0   ...      4        3      4     1     1      3        6   5   6   6
# 238 ...      2        1      1     1     1      3        2  13  11  11
# 237 ...      4        5      2     1     1      5       20  13  12  12
# 236 ...      4        4      2     5     5      4        4  14  13  13
# 235 ...      5        3      3     1     3      2       10  11   9  10
#
# [5 rows x 33 columns]

# %%
#not req
data.sort_values(by=['address', 'school'],
        ascending=[True, False]).head()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 349     MS   M   18       R     GT3       T     3     2     other     other
# 350     MS   M   19       R     GT3       T     1     1     other  services
# 353     MS   M   19       R     GT3       T     1     1     other     other
# 354     MS   M   17       R     GT3       T     4     3  services     other
# 356     MS   F   17       R     GT3       T     4     4   teacher  services
#
#     ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 349 ...      2        5      5     5     5      5       10  11  13  13
# 350 ...      5        4      4     3     3      2        8   8   7   8
# 353 ...      4        4      4     3     3      5        4   8   8   8
# 354 ...      4        5      5     1     3      2        4  13  11  11
# 356 ...      4        3      3     1     2      5        4  12  13  13
#
# [5 rows x 33 columns]

# %%
#not req#mean of 1 header
data['age'].mean()
# Out:
# 16.696202531645568

# %%
#not req
data[data['age'] == 1].mean()
# Out:
# school       NaN
# sex          NaN
# age          NaN
# address      NaN
# famsize      NaN
# Pstatus      NaN
# Medu         NaN
# Fedu         NaN
# Mjob         NaN
# Fjob         NaN
# reason       NaN
# guardian     NaN
# traveltime   NaN
# studytime    NaN
# failures     NaN
# schoolsup    NaN
# famsup       NaN
# paid         NaN
# activities   NaN
# nursery      NaN
# higher       NaN
# internet     NaN
# romantic     NaN
# famrel       NaN
# freetime     NaN
# goout        NaN
# Dalc         NaN
# Walc         NaN
# health       NaN
# absences     NaN
# G1           NaN
# G2           NaN
# G3           NaN
# dtype: float64

# %%
#not req#Data frame indexing by name.Here ':' indicates the range
data.loc[0:10,'age':'studytime']
# Out:
#     age address famsize Pstatus  Medu  Fedu      Mjob      Fjob      reason  \
# 0    18       U     GT3       A     4     4   at_home   teacher      course
# 1    17       U     GT3       T     1     1   at_home     other      course
# 2    15       U     LE3       T     1     1   at_home     other       other
# 3    15       U     GT3       T     4     2    health  services        home
# 4    16       U     GT3       T     3     3     other     other        home
# 5    16       U     LE3       T     4     3  services     other  reputation
# 6    16       U     LE3       T     2     2     other     other        home
# 7    17       U     GT3       A     4     4     other   teacher        home
# 8    15       U     LE3       A     3     2  services     other        home
# 9    15       U     GT3       T     3     4     other     other        home
# 10   15       U     GT3       T     4     4   teacher    health  reputation
#
#    guardian  traveltime  studytime
# ...

# %%
#not req #Data frame indexing by number.The firt instruction asks for the number of rows and second indicates the columns for fetching data
data.iloc[0:5,0:10]
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other

# %%
#not req#If data is required from very first row
data.iloc[:1,0:10]
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher

# %%
#not req#Not sure
data.apply(np.max)
# Out:
# school                MS
# sex                 True
# age                   22
# address                U
# famsize              LE3
# Pstatus                T
# Medu                   4
# Fedu                   4
# Mjob             teacher
# Fjob             teacher
# reason        reputation
# guardian           other
# traveltime             4
# studytime              4
# failures               3
# schoolsup            yes
# famsup               yes
# paid                 yes
# activities           yes
# nursery              yes
# higher               yes
# internet             yes
# romantic             yes
# famrel                 5
# freetime               5
# goout                  5
# Dalc                   5
# Walc                   5
# health                 5
# absences              75
# G1                    19
# G2                    19
# G3                    20
# dtype: object

# %%
#not req
data[data['school'].apply(lambda school: school[0] == 'W')].head()
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, higher, internet, romantic, famrel, freetime, goout, Dalc, Walc, health, absences, G1, G2, G3]
# Index: []
#
# [0 rows x 33 columns]

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x="G1",data=data)

# %%
sns.set(style="whitegrid")
ax = sns.countplot(x="G2",data=data)

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x="G3",data=data)

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x="school",data=data)

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x="sex",data=data)

# %%
sns.set(style="whitegrid")
ax = sns.countplot(x="age", hue="G1", data=data)

# %% [markdown]
# Age vs G1 grades

# %%
sns.set(style="whitegrid")
ax = sns.countplot(x="age", hue="G2", data=data)

# %% [markdown]
# Age vs G2 grades

# %%
sns.set(style="whitegrid")
ax = sns.countplot(x="G3", hue="age", data=data)

# %%
sns.distplot(data['age'])
# Out:
# C:\Users\personal\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
Here we can see a multimodal conti nuous variable

# %%
sns.boxplot(x="G3", y="age", data=data,
            whis="range", palette="vlag")

# %% [markdown]
# Here we can observe significance difference in median of feature 'age' as per different group of grades (G2). So we can infer that age has a significant effect on G2.

# %%
#not req
sns.boxplot(x="G3", y="age", data=data,
            whis="range", palette="vlag")

# %%
sns.boxplot(x="G3", data=data)

# %%
sns.boxplot(x="G3", y="internet", data=data,
            whis="range", palette="vlag")

# %%
sns.boxplot(x="G3", y="absences", data=data,
            whis="range", palette="vlag")

# %%
import matplotlib.pyplot as plt
sns.pairplot(data, kind="scatter")
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-15c0b7d6fe3e> in <module>
#       1 import matplotlib.pyplot as plt
#       2 sns.pairplot(data, kind="scatter")
# ----> 3 plot.show()
#
# NameError: name 'plot' is not defined

# %% [markdown]
# 1Here we can see from the pair plot that no features are seems to be continuous in natutre.Only the feature 'age'and 'absences'  can be considered as continuous. So as an inference we will check realition betweek all the catagorical variables (except 'age' and 'absences') with our terget feature G3.
